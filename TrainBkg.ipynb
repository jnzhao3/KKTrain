# %% [markdown]
# # Hit classification

# %% [markdown]
# In this notebook we will try to use Keras and XGBoost in order to distinguish between _true_ conversion electron hits and _fake_ conversion electron hits.

# %%
import uproot 
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import os
import datetime
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, ReLU
from tensorflow.keras.optimizers import SGD
import tensorflow.keras.layers
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from xgboost import XGBClassifier
# Out:
# 2022-12-29 12:05:05.482892: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# First of all we use [uproot](https://uproot.readthedocs.io/en/latest/), a library to reading ROOT files in pure Python and NumPy, to open the `trkana` tree in the `TAKK` folder of the `KKSM01.root` file. We only need certain branches, so we apply a filter to read only `de`, `detsh`, `detshmc`, and `demc`. We then apply a mask to our tree to select only good fits.
#
# In our problem we have a different number of signal and background entries in our input dataset. There are several techniques avaialable for _unbalanced_ datasets. Here we are using the most naive one, which is just using $\min(N_{sig}, N_{bkg})$ events. Then, we divide our input into the _training_, _validation_, and _test_ datasets.  Note that the datasets must be pruned to the nearest multiple of the batch size, otherwise the gradient calculation fails.

# %%
input_dataset = np.empty
temp = np.empty
signal = np.empty
backgnd = np.empty
filelist = os.environ['KKTrainBkgFiles']
print("Using files in " + filelist)
files = open(filelist, 'r')
for filename in files:
    print("Processing: " + filename)    
    with uproot.open(filename) as file:
        trkana = file["TAKK"]["trkana"].arrays(filter_name="/de|detsh|detshmc|demc/i")
        trkana = trkana[(trkana['de.goodfit']==1)&(trkana['de.status']>0)&(trkana['demc.proc']==167)]
        hstate = ak.concatenate(trkana['detsh.state']).to_numpy()
        udoca = ak.concatenate(trkana['detsh.udoca']).to_numpy()
        udoca = np.absolute(udoca)
        rdrift = ak.concatenate(trkana['detsh.cdrift']).to_numpy()
        tottdrift = ak.concatenate(trkana['detsh.tottdrift']).to_numpy()
        edep = ak.concatenate(trkana['detsh.edep']).to_numpy()
        udocavar = ak.concatenate(trkana['detsh.udocavar']).to_numpy()
        wdist = ak.concatenate(trkana['detsh.wdist']).to_numpy()
        uupos = ak.concatenate(trkana['detsh.uupos']).to_numpy()
        rho = np.square(ak.concatenate(trkana['detsh.poca.fCoordinates.fX']).to_numpy())
        rho = np.add(rho,np.square(ak.concatenate(trkana['detsh.poca.fCoordinates.fY']).to_numpy()))
        rho = np.sqrt(rho)
        print("Processed file " + filename + " with %s hits"%hstate.shape[0])
        temp = np.vstack((udoca, rdrift, udocavar, tottdrift, edep,  wdist, uupos, rho)).T
        if input_dataset is np.empty:
            input_dataset = temp
        else:
            input_dataset = np.concatenate((input_dataset, temp))
        mcrel = []
        for i, this_dt in enumerate(trkana['detsh.state']):
            mcrel.extend(trkana['detshmc.rel._rel'][i][:len(this_dt)])
        mcrel = np.array(mcrel)
        sig = (hstate>-2) & (mcrel==0)
        bkg = (hstate>-2) & (mcrel==-1)
        if signal is np.empty:
            signal = sig
            backgnd = bkg
        else:
            signal = np.concatenate((signal,sig))
            backgnd = np.concatenate((backgnd,bkg))
nhits=len(input_dataset)
print("Total dataset %s hits"%nhits)
# Out:
# Using files in /Users/brownd/data/64709829/files.txt
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000005.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000005.root
#  with 588926 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000008.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000008.root
#  with 580427 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000011.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000011.root
#  with 584978 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000012.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000012.root
#  with 576789 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000018.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000018.root
#  with 589476 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000023.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000023.root
#  with 580370 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000024.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000024.root
#  with 584645 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000026.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000026.root
#  with 585211 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000031.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000031.root
#  with 578183 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000032.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000032.root
#  with 586297 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000034.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000034.root
#  with 578317 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000050.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000050.root
#  with 577933 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000059.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000059.root
#  with 141091 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000062.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000062.root
#  with 579153 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000073.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000073.root
#  with 579721 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000104.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000104.root
#  with 586231 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000110.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000110.root
#  with 580068 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000120.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000120.root
#  with 580017 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000128.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000128.root
#  with 584187 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000135.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000135.root
#  with 579008 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000170.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000170.root
#  with 572642 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000173.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000173.root
#  with 577101 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000202.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000202.root
#  with 407814 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000256.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000256.root
#  with 586169 hits
# Processing: /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000390.root
#
# Processed file /Users/brownd/data/64709829/nts.brownd.KKDrift.KKDS1.001210_00000390.root
#  with 581207 hits
# Total dataset 13925961 hits

# %%
min_len = min(len(input_dataset[signal]), len(input_dataset[backgnd]))
bsize=32
# I need to double the batch_size when truncating as we divide the sample in half later for training
tsize=2*bsize
min_len = min_len - min_len%tsize
print("Training on %s matched hits"%min_len)
signal_dataset = input_dataset[signal][:min_len]
bkg_dataset = input_dataset[backgnd][:min_len]

balanced_input = np.concatenate((signal_dataset, bkg_dataset))
y_balanced_input = np.concatenate((np.ones(signal_dataset.shape[0]), np.zeros(bkg_dataset.shape[0])))

n_variables = balanced_input.shape[1]

x_ce_train, x_ce_test, y_ce_train, y_ce_test = train_test_split(balanced_input, y_balanced_input, test_size=0.5, random_state=42)
x_ce_test, x_ce_valid, y_ce_test, y_ce_valid = train_test_split(x_ce_test, y_ce_test, test_size=0.5, random_state=42)
# Out:
# Training on 32256 matched hits

# %%
udoca_sig = []
tottdrift_sig = []
rdrift_sig = []
udocavar_sig = []
edep_sig = []
wdist_sig = []
uupos_sig = []
rho_sig = []

for i in range(signal_dataset.shape[0]):
    udoca_sig.append(signal_dataset[i][0])
    
for i in range(signal_dataset.shape[0]):
    rdrift_sig.append(signal_dataset[i][1])
    
for i in range(signal_dataset.shape[0]):
    udocavar_sig.append(signal_dataset[i][2])

for i in range(signal_dataset.shape[0]):
    tottdrift_sig.append(signal_dataset[i][3])
    
for i in range(signal_dataset.shape[0]):
    edep_sig.append(signal_dataset[i][4])

for i in range(signal_dataset.shape[0]):
    wdist_sig.append(signal_dataset[i][5])

for i in range(signal_dataset.shape[0]):
    uupos_sig.append(signal_dataset[i][6])
    
for i in range(signal_dataset.shape[0]):
    rho_sig.append(signal_dataset[i][7])

# %%
udoca_back = []
tottdrift_back = []
rdrift_back = []
udocavar_back = []
edep_back = []
wdist_back = []
uupos_back = []
rho_back = []
    
for i in range(bkg_dataset.shape[0]):
    udoca_back.append(bkg_dataset[i][0])
    
for i in range(bkg_dataset.shape[0]):
    rdrift_back.append(bkg_dataset[i][1])
    
for i in range(bkg_dataset.shape[0]):
    udocavar_back.append(bkg_dataset[i][2])

for i in range(bkg_dataset.shape[0]):
    tottdrift_back.append(bkg_dataset[i][3])

for i in range(bkg_dataset.shape[0]):
    edep_back.append(bkg_dataset[i][4])
    
for i in range(bkg_dataset.shape[0]):
    wdist_back.append(bkg_dataset[i][5])

for i in range(bkg_dataset.shape[0]):
    uupos_back.append(bkg_dataset[i][6])
    
for i in range(bkg_dataset.shape[0]):
    rho_back.append(bkg_dataset[i][7])

# %%
plt.hist(udoca_sig,label="Unbiased DOCA Signal", bins=100,range=(0,10))
plt.hist(udoca_back,label="Unbiased DOCA Background", histtype='step', bins=100,range=(0,10))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(rdrift_sig,label="Radius Drift Signal", bins=50,range=(-2,3.0))
plt.hist(rdrift_back,label="Radius Drift Background", histtype='step', bins=50, range=(-2,3.0))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(udocavar_sig,label="DOCA Variance Signal", bins=50,range=(0,3))
plt.hist(udocavar_back,label="DOCA Variance Background", histtype='step', bins=50,range=(0,3))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(tottdrift_sig,label="Time-Over-Threshold Drift Time Signal", bins=50, range=(0,40))
plt.hist(tottdrift_back,label="Time-Over-Threshold Drift Time Background", histtype='step', bins=50,range=(0,40))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(edep_sig,label="Energy Deposition Signal",bins=50,range=(0,0.007))
plt.hist(edep_back,label="Energy Deposition Background", histtype='step', bins=50, range=(0,0.007))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(wdist_sig,label="Wire Distance Signal", bins=50, range=(-800,800))
plt.hist(wdist_back,label="Wire Distance Background", histtype='step', bins=50, range=(-800,800))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(uupos_sig,label="Unbiased U Position Signal", bins=50, range=(-800,800))
plt.hist(uupos_back,label="Unbiased U Position Background", histtype='step', bins=50, range=(-800,800))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(rho_sig,label="Rho Signal", bins=50, range=(350,700))
plt.hist(rho_back,label="Rho Background", histtype='step', bins=50, range=(350,700))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Then, we concatenate each hit variables into a single, large numpy array. These arrays are then stacked in a single bi-dimensional array with `np.vstack`, which will be our input dataset used for the training of the machine learning algorithms.

# %% [markdown]
# Here we then assign a label to each hit as _signal_ or _background_, depending on the Monte Carlo truth information. Since the dimension of  `detshmc.rel._rel` is not guaranteed to be the same as the dimension of `detsh` we need to loop over all the entries.

# %% [markdown]
# ## Create and train a multi-layer perceptron

# %% [markdown]
# Here we create a _multi-layer perceptron_ (MLP) model which consists of 3 fully-connected (or _dense_) layers, each one followed by a _dropout_ layer, which helps to avoid overfitting. The model is trained using the [Adam](https://arxiv.org/abs/1412.6980) optimizer and trained for 50 epochs or until the validation loss doesn't improve for 5 epochs (`early_stop`). The model we save must be created first, with an explicit input layer with explicit batch_size, otherwise it can't be parsed by the TMVA::SOFIE parser we use to generate a C++ inference function downstream.

# %% [markdown]
# The output model must have batch_size=1, otherwise the SOFIE inference function will assume that many input variables at a time.  Training (gradient calculation) however is much more efficient with a larger batch size, so we construct a separate model for that.  After training and before saving, we'll copy the weights (which don't depend on batch_size) from the trained model to the output model.  This should be unnecessary in the next verison of ROOT.

# %%
lay0=Input(shape=(n_variables,),batch_size=1)
lay1=Dense(n_variables+1, activation='relu')(lay0)
lay2=Dense(n_variables+1, activation='relu')(lay1)
lay3=Dense(n_variables+1, activation='relu')(lay2)
lay4=Dense(1,activation='sigmoid')(lay3)
output_model=Model(inputs=lay0,outputs=lay4)

opt = Adam(learning_rate=1e-3)
input=Input(shape=(n_variables,),batch_size=bsize)
x=Dense(n_variables+1, activation='relu')(input)
x=Dense(n_variables+1, activation='relu')(x)
x=Dense(n_variables+1, activation='relu')(x)
output=Dense(1,activation='sigmoid')(x)
model_ce=Model(inputs=input,outputs=output)
model_ce.compile(loss='binary_crossentropy',metrics='accuracy',optimizer=opt)
early_stop = EarlyStopping(monitor='val_loss', patience=10, min_delta=1e-5, restore_best_weights=True)
history_ce = model_ce.fit(x_ce_train, y_ce_train,
                          batch_size=bsize,
                          epochs=200,
                          verbose=1,
                          validation_data=(x_ce_valid, y_ce_valid),
                          callbacks=[early_stop]
                         )
# Out:
# Epoch 1/200
# 2022-12-29 12:15:21.381448: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1008/1008 [==============================] - 2s 1ms/step - loss: 11.0762 - accuracy: 0.6300 - val_loss: 0.6363 - val_accuracy: 0.6472
# Epoch 2/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.6119 - accuracy: 0.6701 - val_loss: 0.6095 - val_accuracy: 0.6759
# Epoch 3/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.5902 - accuracy: 0.6896 - val_loss: 0.5808 - val_accuracy: 0.7011
# Epoch 4/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.5715 - accuracy: 0.7089 - val_loss: 0.5674 - val_accuracy: 0.7190
# Epoch 5/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.5519 - accuracy: 0.7329 - val_loss: 0.5378 - val_accuracy: 0.7539
# Epoch 6/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.5108 - accuracy: 0.7749 - val_loss: 0.5115 - val_accuracy: 0.7590
# Epoch 7/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.4647 - accuracy: 0.8020 - val_loss: 0.4622 - val_accuracy: 0.7973
# Epoch 8/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.4400 - accuracy: 0.8097 - val_loss: 0.4345 - val_accuracy: 0.8061
# Epoch 9/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.4160 - accuracy: 0.8231 - val_loss: 0.3997 - val_accuracy: 0.8305
# Epoch 10/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3855 - accuracy: 0.8397 - val_loss: 0.3790 - val_accuracy: 0.8423
# Epoch 11/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3602 - accuracy: 0.8573 - val_loss: 0.3527 - val_accuracy: 0.8627
# Epoch 12/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3455 - accuracy: 0.8648 - val_loss: 0.3569 - val_accuracy: 0.8567
# Epoch 13/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3365 - accuracy: 0.8698 - val_loss: 0.3339 - val_accuracy: 0.8712
# Epoch 14/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3274 - accuracy: 0.8751 - val_loss: 0.3608 - val_accuracy: 0.8544
# Epoch 15/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3153 - accuracy: 0.8779 - val_loss: 0.3263 - val_accuracy: 0.8730
# Epoch 16/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3043 - accuracy: 0.8834 - val_loss: 0.2945 - val_accuracy: 0.8845
# Epoch 17/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2925 - accuracy: 0.8852 - val_loss: 0.3118 - val_accuracy: 0.8725
# Epoch 18/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2858 - accuracy: 0.8866 - val_loss: 0.2921 - val_accuracy: 0.8852
# Epoch 19/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2826 - accuracy: 0.8885 - val_loss: 0.2857 - val_accuracy: 0.8882
# Epoch 20/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2737 - accuracy: 0.8922 - val_loss: 0.2753 - val_accuracy: 0.8928
# Epoch 21/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2707 - accuracy: 0.8938 - val_loss: 0.2737 - val_accuracy: 0.8943
# Epoch 22/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2695 - accuracy: 0.8956 - val_loss: 0.2649 - val_accuracy: 0.8971
# Epoch 23/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2670 - accuracy: 0.8949 - val_loss: 0.2730 - val_accuracy: 0.8898
# Epoch 24/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2668 - accuracy: 0.8952 - val_loss: 0.2822 - val_accuracy: 0.8884
# Epoch 25/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2650 - accuracy: 0.8971 - val_loss: 0.2637 - val_accuracy: 0.9001
# Epoch 26/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2655 - accuracy: 0.8952 - val_loss: 0.2901 - val_accuracy: 0.8872
# Epoch 27/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2632 - accuracy: 0.8965 - val_loss: 0.2754 - val_accuracy: 0.8942
# Epoch 28/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2634 - accuracy: 0.8960 - val_loss: 0.2609 - val_accuracy: 0.8992
# Epoch 29/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2621 - accuracy: 0.8965 - val_loss: 0.2636 - val_accuracy: 0.8989
# Epoch 30/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2627 - accuracy: 0.8965 - val_loss: 0.2737 - val_accuracy: 0.8921
# Epoch 31/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2610 - accuracy: 0.8970 - val_loss: 0.2615 - val_accuracy: 0.8974
# Epoch 32/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2606 - accuracy: 0.8988 - val_loss: 0.2707 - val_accuracy: 0.8970
# Epoch 33/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2601 - accuracy: 0.8983 - val_loss: 0.2819 - val_accuracy: 0.8896
# Epoch 34/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2588 - accuracy: 0.8992 - val_loss: 0.2560 - val_accuracy: 0.8996
# Epoch 35/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2586 - accuracy: 0.8996 - val_loss: 0.2598 - val_accuracy: 0.8996
# Epoch 36/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2593 - accuracy: 0.8981 - val_loss: 0.2582 - val_accuracy: 0.8997
# Epoch 37/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2592 - accuracy: 0.8979 - val_loss: 0.2688 - val_accuracy: 0.8945
# Epoch 38/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2578 - accuracy: 0.8987 - val_loss: 0.2627 - val_accuracy: 0.8970
# Epoch 39/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2586 - accuracy: 0.8992 - val_loss: 0.2761 - val_accuracy: 0.8957
# Epoch 40/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2572 - accuracy: 0.8986 - val_loss: 0.2643 - val_accuracy: 0.8962
# Epoch 41/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2558 - accuracy: 0.8988 - val_loss: 0.3020 - val_accuracy: 0.8834
# Epoch 42/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2603 - accuracy: 0.8970 - val_loss: 0.2727 - val_accuracy: 0.8923
# Epoch 43/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2569 - accuracy: 0.8990 - val_loss: 0.2736 - val_accuracy: 0.8893
# Epoch 44/200
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2567 - accuracy: 0.8983 - val_loss: 0.2759 - val_accuracy: 0.8934

# %% [markdown]
# ## Create and train a Boosted Decision Tree
# Here, instead of using a MLP, we use a [_Gradient Boosted Decision Tree_](https://xgboost.readthedocs.io/en/stable/) (BDT) to distinguish between signal (true CE hits) and background (fake CE hits). We use the defualt hyperparameters.

# %%
model_xgboost = XGBClassifier()
model_xgboost.fit(x_ce_train, y_ce_train)
# Out:
# [12:16:10] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_44tbtwf8c1/croots/recipe/xgboost-split_1659548960882/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/brownd/mambaforge/envs/KKTrain/lib/python3.10/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=16,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# Here we can finally apply our two models (the MLP and the BDT) to our test datasets and create the corresponding ROC curves.

# %%
#prediction_ce = model_ce.predict(x_ce_test).ravel()
prediction_ce = model_ce.predict(x_ce_test)
fpr_ce, tpr_ce, th_ce = roc_curve(y_ce_test,  prediction_ce)
auc_ce = roc_auc_score(y_ce_test, prediction_ce)
# Out:
# 504/504 [==============================] - 0s 542us/step

# %%
prediction_xgboost = model_xgboost.predict_proba(x_ce_test)[:,1]
fpr_xgboost, tpr_xgboost, th_xgboost = roc_curve(y_ce_test,  prediction_xgboost)
auc_xgboost = roc_auc_score(y_ce_test, prediction_xgboost)

# %% [markdown]
# The plot of the ROC curves clearly shows that the BDT outperforms the MLP. In principle, however, it should be possible to improve the MLP performances by optimizing the hyperparameters (learning rate, hidden layers, activation functions, etc.).

# %%
fig, ax = plt.subplots(1,1)
ax.plot(tpr_ce,1-fpr_ce,label=f'MLP AUC: {auc_ce:.3f}')
ax.plot(tpr_xgboost,1-fpr_xgboost,label=f'BDT AUC: {auc_xgboost:.3f}')

ax.legend()
ax.set_aspect("equal")
ax.set_xlabel("Signal efficiency")
ax.set_ylabel("Background rejection")
ax.set_xlim(0,1.05)
ax.set_ylim(0,1.05)
fig.savefig("TrainBkg.pdf")

# %% [markdown]
# Now we save our model in HDF5 format.  This can be used as input to the SOFIE parser.  Note that the kernel must be restarted when saving this file, as re-running individual cells increments the layer numbers in the hdf5 file, causing the SOFIE parser to fail.

# %%
output_model.set_weights(model_ce.get_weights())
output_model.summary()
output_model.save("TrainBkg.h5")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 8)]                  0
#
#  dense (Dense)               (1, 9)                    81
#
#  dense_1 (Dense)             (1, 9)                    90
#
#  dense_2 (Dense)             (1, 9)                    90
#
#  dense_3 (Dense)             (1, 1)                    10
#
# =================================================================
# Total params: 271
# Trainable params: 271
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
