# %% [markdown]
# # Hit classification

# %% [markdown]
# In this notebook we will try to use Keras and XGBoost in order to distinguish between _true_ conversion electron hits and _fake_ conversion electron hits.

# %%
import uproot 
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import xgboost
import os
import datetime
import tensorflow as tf

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from xgboost import XGBClassifier

# %%
rm -rf ./logs/

# %% [markdown]
# Files are read from the 'KKTrainData' environment variable, which should point to a .txt file which lists the
# actual .root files you want to analyze. You must define KKTrainData before launching Juypterlab.
# A good way to create it is (for example):
#
# myunix> ls -1 /Users/brownd/data/39501509/*.root > /Users/brownd/data/myKKTrainFiles.txt
#
# myunix> export KKTrainData=\"/Users/brownd/data/myKKTrainFiles.txt
#
# Note that you can filter or edit the myKKTrainFiles.txt to include any subset of files you want
#
# First of all we use [uproot](https://uproot.readthedocs.io/en/latest/), a library to reading ROOT files in pure Python and NumPy, to open the `trkana` tree in the `TAKK` folder of the `KKSM01.root` file. We only need certain branches, so we apply a filter to read only `de`, `detsh`, `detshmc`, and `demc`. We then apply a mask to our tree to select only good fits.

# %% [markdown]
# Then, we select the first 10000 events in the tree and concatenate the lists of the hit variables in a single, large array. These 5 arrays are then stacked in a single bi-dimensional array with `np.vstack`, which will be our input dataset used for the training of the machine learning algorithms.

# %%
input_dataset = np.empty
temp = np.empty
mcrel = []
n_events = 100000

filelist = os.environ['KKTrainData']
print("Using files in " + filelist)
files = open(filelist, 'r')
for filename in files:
    with uproot.open(filename) as file:
        trkana = file["TAKK"]["trkana"].arrays(filter_name="/de|detsh|detshmc|demc/i")
        trkana = trkana[(trkana['de.goodfit']==1)&(trkana['de.status']>0)&(trkana['demc.proc']==167)]
        
    print("Processing: " + filename)    
    udt = np.add(ak.concatenate(trkana['detsh.udt'][:n_events]).to_numpy(), ak.concatenate(trkana['detsh.udt'][:n_events]).to_numpy())  
    udoca = ak.concatenate(trkana['detsh.udoca'][:n_events]).to_numpy()
    tottdrift = ak.concatenate(trkana['detsh.tottdrift'][:n_events]).to_numpy()
    rdrift = ak.concatenate(trkana['detsh.rdrift'][:n_events]).to_numpy()
    edep = ak.concatenate(trkana['detsh.edep'][:n_events]).to_numpy()
    udocavar = ak.concatenate(trkana['detsh.udocavar'][:n_events]).to_numpy()
    wdist = ak.concatenate(trkana['detsh.wdist'][:n_events]).to_numpy()
    uupos = ak.concatenate(trkana['detsh.uupos'][:n_events]).to_numpy()
    rho = np.square(ak.concatenate(trkana['detsh.poca.fCoordinates.fX'][:n_events]).to_numpy())
    rho = np.add(rho,np.square(ak.concatenate(trkana['detsh.poca.fCoordinates.fY'][:n_events]).to_numpy()))
    rho = np.sqrt(rho)
    
    temp = np.vstack((udt,udoca,tottdrift,rdrift,edep, udocavar, wdist, uupos, rho)).T
    if input_dataset is np.empty:
        input_dataset = temp
    else:
        input_dataset = np.concatenate((input_dataset, temp))
        
    for i, this_dt in enumerate(trkana['detsh.udt'][:n_events]):
        mcrel.extend(trkana['detshmc.rel._rel'][i][:len(this_dt)])
# Out:
# Using files in /Users/brownd/data/39501509/myfiles.txt
# Processing: /Users/brownd/data/39501509/nts.brownd.KKSeed.KKSM.001210_00000005.root
#
# Processing: /Users/brownd/data/39501509/nts.brownd.KKSeed.KKSM.001210_00000008.root

# %%
input_dataset.size
# Out:
# 10347111

# %% [markdown]
# Here we then assign a label to each hit as _signal_ or _background_, depending on the Monte Carlo truth information. Since the dimension of  `detshmc.rel._rel` is not guaranteed to be the same as the dimension of `detsh` we need to loop over all the entries.

# %%
mcrel = np.array(mcrel)
true_ce = mcrel==0
    
signal = true_ce
bkg = mcrel ==-1

# %% [markdown]
# In our problem we have a different number of signal and background entries in our input dataset. There are several techniques avaialable for _unbalanced_ datasets. Here we are using the most naive one, which is just using $\min(N_{sig}, N_{bkg})$ events. Then, we divide our input into the _training_, _validation_, and _test_ datasets.

# %%
min_len = min(len(input_dataset[signal]), len(input_dataset[bkg]))
signal_dataset = input_dataset[signal][:min_len]
bkg_dataset = input_dataset[bkg][:min_len]

balanced_input = np.concatenate((signal_dataset, bkg_dataset))
y_balanced_input = np.concatenate((np.ones(signal_dataset.shape[0]), np.zeros(bkg_dataset.shape[0])))

n_variables = balanced_input.shape[1]

x_ce_train, x_ce_test, y_ce_train, y_ce_test = train_test_split(balanced_input, y_balanced_input, test_size=0.5, random_state=42)
x_ce_test, x_ce_valid, y_ce_test, y_ce_valid = train_test_split(x_ce_test, y_ce_test, test_size=0.5, random_state=42)

# %%
udt_sig = signal_dataset[0]
udoca_sig = signal_dataset[1]
tottdrift_sig = signal_dataset[2]
rdrift_sig = signal_dataset[3]
edep_sig = signal_dataset[4]
udocavar_sig = signal_dataset[5]

udt_back = bkg_dataset[0]
udoca_back = bkg_dataset[1]
tottdrift_back = bkg_dataset[2]
rdrift_back = bkg_dataset[3]
edep_back = bkg_dataset[4]
udocavar_back = bkg_dataset[5]

plt.plot(udt_sig,label="Unbiased Dt Signal")
plt.plot(udt_back,label="Unbiased Dt Background")
plt.legend()

plt.plot(udoca_sig,label="Unbiased DOCA Signal")
plt.plot(udoca_back,label="Unbiased DOCA Background")
plt.legend()

plt.plot(tottdrift_sig,label="Time-Over-Threshold Drift Time Signal")
plt.plot(tottdrift_back,label="Time-Over-Threshold Drift Time Background")
plt.legend()

plt.plot(rdrift_sig,label="Radius Drift Signal")
plt.plot(rdrift_back,label="Radius Drift Background")
plt.legend()

plt.plot(edep_sig,label="Energy Deposition Signal")
plt.plot(edep_back,label="Energy Deposition Background")
plt.legend()

plt.plot(udocavar_sig,label="Unbiased DOCA Variance Signal")
plt.plot(udocavar_back,label="Unbiased DOCA Variance Background")
plt.legend()

# %% [markdown]
# ## Create and train a multi-layer perceptron

# %% [markdown]
# Here we create a _multi-layer perceptron_ (MLP) model which consists of 3 fully-connected (or _dense_) layers, each one followed by a _dropout_ layer, which helps to avoid overfitting. The model is trained using the [Adam](https://arxiv.org/abs/1412.6980) optimizer and trained for 50 epochs or until the validation loss doesn't improve for 5 epochs (`early_stop`).

# %%
opt = Adam(learning_rate=1e-3)

model_ce = Sequential()
model_ce.add(Dense(n_variables*8, activation='relu', input_shape=(n_variables,)))
model_ce.add(Dropout(0.2))
model_ce.add(Dense(n_variables*8, activation='relu'))
model_ce.add(Dropout(0.2))
model_ce.add(Dense(n_variables*8, activation='relu'))
model_ce.add(Dropout(0.2))
model_ce.add(Dense(1, activation='sigmoid'))
model_ce.compile(loss='binary_crossentropy',
                 metrics='accuracy',
                 optimizer=opt)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

early_stop = EarlyStopping(monitor='val_loss', patience=5)
# history_ce = model_ce.fit(x_ce_train, y_ce_train,
#                           epochs=50,
#                           verbose=1,
#                           validation_data=(x_ce_valid, y_ce_valid),
#                           callbacks=[early_stop])

history_ce = model_ce.fit(x_ce_train, y_ce_train,
                          epochs=50,
                          verbose=1,
                          validation_data=(x_ce_valid, y_ce_valid),
                          callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 374/374 [==============================] - 2s 4ms/step - loss: 2.6832 - accuracy: 0.6307 - val_loss: 0.4911 - val_accuracy: 0.7861
# Epoch 2/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.6268 - accuracy: 0.7102 - val_loss: 0.4627 - val_accuracy: 0.7831
# Epoch 3/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.5217 - accuracy: 0.7475 - val_loss: 0.4305 - val_accuracy: 0.8038
# Epoch 4/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.4948 - accuracy: 0.7670 - val_loss: 0.4264 - val_accuracy: 0.8145
# Epoch 5/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.4716 - accuracy: 0.7829 - val_loss: 0.4073 - val_accuracy: 0.8245
# Epoch 6/50
# 374/374 [==============================] - 2s 4ms/step - loss: 0.4480 - accuracy: 0.7995 - val_loss: 0.3977 - val_accuracy: 0.8287
# Epoch 7/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.4380 - accuracy: 0.8069 - val_loss: 0.3857 - val_accuracy: 0.8327
# Epoch 8/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.4183 - accuracy: 0.8157 - val_loss: 0.3653 - val_accuracy: 0.8459
# Epoch 9/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.4046 - accuracy: 0.8255 - val_loss: 0.3494 - val_accuracy: 0.8541
# Epoch 10/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.3864 - accuracy: 0.8375 - val_loss: 0.3297 - val_accuracy: 0.8646
# Epoch 11/50
# 374/374 [==============================] - 2s 4ms/step - loss: 0.3699 - accuracy: 0.8448 - val_loss: 0.3106 - val_accuracy: 0.8735
# Epoch 12/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.3491 - accuracy: 0.8558 - val_loss: 0.2876 - val_accuracy: 0.8855
# Epoch 13/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.3300 - accuracy: 0.8702 - val_loss: 0.2562 - val_accuracy: 0.9016
# Epoch 14/50
# 374/374 [==============================] - 2s 4ms/step - loss: 0.2979 - accuracy: 0.8842 - val_loss: 0.2226 - val_accuracy: 0.9203
# Epoch 15/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.2728 - accuracy: 0.8989 - val_loss: 0.2127 - val_accuracy: 0.9258
# Epoch 16/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.2641 - accuracy: 0.9036 - val_loss: 0.2027 - val_accuracy: 0.9308
# Epoch 17/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.2512 - accuracy: 0.9101 - val_loss: 0.1918 - val_accuracy: 0.9375
# Epoch 18/50
# 374/374 [==============================] - 2s 5ms/step - loss: 0.2393 - accuracy: 0.9167 - val_loss: 0.1884 - val_accuracy: 0.9368
# Epoch 19/50
# 374/374 [==============================] - 3s 8ms/step - loss: 0.2296 - accuracy: 0.9179 - val_loss: 0.1741 - val_accuracy: 0.9423
# Epoch 20/50
# 374/374 [==============================] - 2s 4ms/step - loss: 0.2271 - accuracy: 0.9204 - val_loss: 0.1789 - val_accuracy: 0.9437
# Epoch 21/50
# 374/374 [==============================] - 3s 7ms/step - loss: 0.2228 - accuracy: 0.9225 - val_loss: 0.1683 - val_accuracy: 0.9440
# Epoch 22/50
# 374/374 [==============================] - 3s 7ms/step - loss: 0.2154 - accuracy: 0.9261 - val_loss: 0.1703 - val_accuracy: 0.9465
# Epoch 23/50
# 374/374 [==============================] - 4s 10ms/step - loss: 0.2085 - accuracy: 0.9258 - val_loss: 0.1727 - val_accuracy: 0.9418
# Epoch 24/50
# 374/374 [==============================] - 2s 5ms/step - loss: 0.2060 - accuracy: 0.9305 - val_loss: 0.1724 - val_accuracy: 0.9450
# Epoch 25/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1987 - accuracy: 0.9338 - val_loss: 0.1667 - val_accuracy: 0.9439
# Epoch 26/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1910 - accuracy: 0.9325 - val_loss: 0.1656 - val_accuracy: 0.9408
# Epoch 27/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1893 - accuracy: 0.9328 - val_loss: 0.1500 - val_accuracy: 0.9490
# Epoch 28/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1888 - accuracy: 0.9371 - val_loss: 0.1449 - val_accuracy: 0.9532
# Epoch 29/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1855 - accuracy: 0.9366 - val_loss: 0.1612 - val_accuracy: 0.9479
# Epoch 30/50
# 374/374 [==============================] - 1s 4ms/step - loss: 0.1744 - accuracy: 0.9411 - val_loss: 0.1454 - val_accuracy: 0.9527
# Epoch 31/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1762 - accuracy: 0.9393 - val_loss: 0.1481 - val_accuracy: 0.9499
# Epoch 32/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1809 - accuracy: 0.9393 - val_loss: 0.1557 - val_accuracy: 0.9489
# Epoch 33/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1705 - accuracy: 0.9410 - val_loss: 0.1479 - val_accuracy: 0.9442
# Epoch 34/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1672 - accuracy: 0.9440 - val_loss: 0.1469 - val_accuracy: 0.9504
# Epoch 35/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1673 - accuracy: 0.9417 - val_loss: 0.1405 - val_accuracy: 0.9534
# Epoch 36/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1716 - accuracy: 0.9421 - val_loss: 0.1469 - val_accuracy: 0.9477
# Epoch 37/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1621 - accuracy: 0.9431 - val_loss: 0.1465 - val_accuracy: 0.9500
# Epoch 38/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1679 - accuracy: 0.9432 - val_loss: 0.1389 - val_accuracy: 0.9540
# Epoch 39/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1649 - accuracy: 0.9443 - val_loss: 0.1352 - val_accuracy: 0.9529
# Epoch 40/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1652 - accuracy: 0.9424 - val_loss: 0.1357 - val_accuracy: 0.9522
# Epoch 41/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1589 - accuracy: 0.9455 - val_loss: 0.1851 - val_accuracy: 0.9248
# Epoch 42/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1623 - accuracy: 0.9451 - val_loss: 0.1312 - val_accuracy: 0.9545
# Epoch 43/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1633 - accuracy: 0.9449 - val_loss: 0.1545 - val_accuracy: 0.9474
# Epoch 44/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1629 - accuracy: 0.9454 - val_loss: 0.1384 - val_accuracy: 0.9519
# Epoch 45/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1580 - accuracy: 0.9453 - val_loss: 0.1401 - val_accuracy: 0.9519
# Epoch 46/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1509 - accuracy: 0.9484 - val_loss: 0.1336 - val_accuracy: 0.9534
# Epoch 47/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1615 - accuracy: 0.9454 - val_loss: 0.1424 - val_accuracy: 0.9504
# Epoch 48/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1527 - accuracy: 0.9479 - val_loss: 0.1450 - val_accuracy: 0.9524
# Epoch 49/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1572 - accuracy: 0.9466 - val_loss: 0.1359 - val_accuracy: 0.9539
# Epoch 50/50
# 374/374 [==============================] - 1s 3ms/step - loss: 0.1505 - accuracy: 0.9487 - val_loss: 0.1333 - val_accuracy: 0.9512

# %%
plt.plot(history_ce.history['val_loss'],label="val loss")
plt.plot(history_ce.history['loss'],label="loss")
plt.legend()

# %load_ext tensorboard
#rm -rf ./logs/
# %tensorboard --logdir logs/fit
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 67279), started 2:20:20 ago. (Use '!kill 67279' to kill it.)
#       <iframe id="tensorboard-frame-9ba6ade10c66c4be" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9ba6ade10c66c4be");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Create and train a Boosted Decision Tree
# Here, instead of using a MLP, we use a [_Gradient Boosted Decision Tree_](https://xgboost.readthedocs.io/en/stable/) (BDT) to distinguish between signal (true CE hits) and background (fake CE hits). We use the defualt hyperparameters.

# %%
model_xgboost = XGBClassifier()
model_xgboost.fit(x_ce_train, y_ce_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %% [markdown]
# Here we can finally apply our two models (the MLP and the BDT) to our test datasets and create the corresponding ROC curves.

# %%
prediction_ce = model_ce.predict(x_ce_test).ravel()
fpr_ce, tpr_ce, th_ce = roc_curve(y_ce_test,  prediction_ce)
auc_ce = roc_auc_score(y_ce_test, prediction_ce)
# Out:
# 187/187 [==============================] - 0s 2ms/step

# %%
prediction_xgboost = model_xgboost.predict_proba(x_ce_test)[:,1]
fpr_xgboost, tpr_xgboost, th_xgboost = roc_curve(y_ce_test,  prediction_xgboost)
auc_xgboost = roc_auc_score(y_ce_test, prediction_xgboost)

# %% [markdown]
# The plot of the ROC curves clearly shows that the BDT outperforms the MLP. In principle, however, it should be possible to improve the MLP performances by optimizing the hyperparameters (learning rate, hidden layers, activation functions, etc.).

# %%
fig, ax = plt.subplots(1,1)
ax.plot(tpr_ce,1-fpr_ce,label=f'MLP AUC: {auc_ce:.2f}')
ax.plot(tpr_xgboost,1-fpr_xgboost,label=f'BDT AUC: {auc_xgboost:.2f}')

ax.legend()
ax.set_aspect("equal")
ax.set_xlabel("Signal efficiency")
ax.set_ylabel("Background rejection")
ax.set_xlim(0,1.05)
ax.set_ylim(0,1.05)
fig.savefig("truece.pdf")
